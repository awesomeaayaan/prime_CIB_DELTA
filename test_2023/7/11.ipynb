# %%
import json
import pandas as pd

file = open(r"D:\BOT_Prime\CIB_DELTA_back\output\data.json")
datas = json.load(file)
df = pd.DataFrame(columns=[
        'Name',
        'DOB', 
        'Gender', 
        'FatherName', 
        'CitizenshipDetails', 
        'PassportDetails', 
        'DrivingLicenseDetails',
        'VoterIDDetails',
        'PANDetails', 
        'IndianEmbassyDetails',
        'BlackLists' 
    ])

num = 0
for data in datas["BulkOffLoading"]["Individuals"]["Item"]:
    dicts = {}
    data_count_list = []
    data_keys = list(data.keys())
    # print(data_keys)
    for data_key in data_keys[:4]:
        dicts[data_key] = data[data_key]
        # print(dicts)
    # for data_key in sorted(data_keys[4:]):
    #     keys = list(data[data_key].keys())
    #     data_count = int(data[data_key][keys[0]])
    #     data_count_list.append(data_count)
    #     print(data_count_list)
    for data_key in data_keys[4:]:
        keys = list(data[data_key].keys())
        data_count = int(data[data_key][keys[0]])
        data_count_list.append(data_count)
        # print(data_count_list)
        if data_count == 1:
            details = data[data_key][keys[1]]
            dicts[data_key] = '|'.join(details.values())
            print(dicts)
            df.loc[len(df)] = dicts
        if data_count > 1:
            details = data[data_key][keys[1]]
            for detail in details:
                dicts[data_key] = '|'.join(detail.values())
                # print(dicts)
                df.loc[len(df)] = dicts
        if data_count == 0:
            continue

        if "BlackList" not in data_key:
            df.loc[len(df)] = dicts
            del dicts[data_key]
            # print(details)
        #     if 'BlackLists' in data_key:
        #         for detail in details:
        #             dicts[data_key] = '|'.join(detail.values())
        #             # print(dicts)
        #             df.loc[len(df)] = dicts
        #             continue
        #     else:
        #         for detail in details:
        #             dicts[data_key] = '|'.join(detail.values())
        #             df.loc[len(df)] = dicts
        # elif data_count == 0:
        #     continue
        # else:
        #     details = data[data_key][keys[1]]
        #     dicts[data_key] = '|'.join(details.values())
        #     print(dicts)
        #     df.loc[len(df)] = dicts
    num +=1
    if num ==6:
        break
# Out:
# {'Name': 'BALRAM PRADHAN', 'DOB': '2015-03-15', 'Gender': 'M', 'FatherName': 'JITENDRA PRADHAN', 'CitizenshipDetails': '2827|2046-01-11|Kathmandu'}
# {'Name': 'BHADRA BARAILI', 'DOB': '2004-11-22', 'Gender': 'M', 'FatherName': 'SAL BAHADUR BARAILI', 'CitizenshipDetails': '2061/30387|2041-08-29|Sankhuwasabha'}
# {'Name': 'BHADRA BARAILI', 'DOB': '2004-11-22', 'Gender': 'M', 'FatherName': 'SAL BAHADUR BARAILI', 'BlackLists': 'Bank and Financial Institutions|15073|2076-07-18|CF|Guarantor'}
# {'Name': 'SUDHA DEVI DARUKA', 'DOB': '2030-01-01', 'Gender': 'F', 'FatherName': 'SAWAR MAL RANGUTA', 'CitizenshipDetails': '10523|2068-08-04|Parsa'}
# {'Name': 'SUDHA DEVI DARUKA', 'DOB': '2030-01-01', 'Gender': 'F', 'FatherName': 'SAWAR MAL RANGUTA', 'BlackLists': 'Bank and Financial Institutions|14770|2076-06-12|CF|Proprietor'}
# {'Name': 'RAJESH RAJ VERMA', 'DOB': '2030-08-22', 'Gender': 'M', 'FatherName': 'KRISHNA RAJ VERMA', 'CitizenshipDetails': '5237|2047-07-20|Saptari'}
# {'Name': 'NEELAM RIJAL', 'DOB': '2029-05-21', 'Gender': 'F', 'FatherName': 'TARAK PRASAD RIJAL', 'CitizenshipDetails': '22961|2052-08-13|Morang'}
# {'Name': 'JIVAN GIRI', 'DOB': '2036-01-29', 'Gender': 'M', 'FatherName': 'RAM CHANDRA GIRI', 'CitizenshipDetails': '2727/5942|2052-04-22|Morang'}
# {'Name': 'JIVAN GIRI', 'DOB': '2036-01-29', 'Gender': 'M', 'FatherName': 'RAM CHANDRA GIRI', 'PANDetails': '304598155|2067-12-09|Jhapa'}
# {'Name': 'JIVAN GIRI', 'DOB': '2036-01-29', 'Gender': 'M', 'FatherName': 'RAM CHANDRA GIRI', 'BlackLists': 'Bank and Financial Institutions|69325|2080-02-29|CF|Guarantor'}

# %%
import json
import pandas as pd

file = open(r"D:\BOT_Prime\CIB_DELTA_back\output\data (1).json")
datas = json.load(file)
df = pd.DataFrame(columns=[
        'Name',
        'DOB', 
        'Gender', 
        'FatherName', 
        'CitizenshipDetails', 
        'PassportDetails', 
        'DrivingLicenseDetails',
        'VoterIDDetails',
        'PANDetails', 
        'CompanyDetails',
        'IndianEmbassyDetails',
        'BlackLists' 
    ])
num = 0
for data in datas["BulkOffLoading"]["Institutions"]["Item"]:
    # for key_value in data:
    # display("--------------------------- REal Data --------------------- \n")
    # display(data)
    dicts = {}
    data_keys = list(data.keys())
    for data_key in data_keys:
        if isinstance(data[data_key], str):
            dicts[data_key] = data[data_key]
        else:
            # maintain Citizenship details
            keys = list(data[data_key].keys())
            data_count = int(data[data_key][keys[0]])
            if data_count > 1:
                details = data[data_key][keys[1]]
                dicts[data_key] = ['|'.join(entry.values()) for entry in details]
            elif data_count == 0:
                dicts[data_key] = ""
            else:
                details = data[data_key][keys[1]]
                dicts[data_key] = '|'.join(details.values())

    dicts['Account_Nature'] = 'Individual'
    dicts['Status'] = 'new'
    # display(f"--------------- Processed Data number {num} -----------------------" )
    # display(dicts)
    num += 1
    if num == 11:
        break

    # appending to df
    df.loc[len(df)] = dicts

# %%
df.head()
# Out:
#                                      Name  DOB  Gender  FatherName  \
# 0           AALI SUB REMIT SEWA PVT. LTD.  NaN     NaN         NaN
# 1                  RECHAL ELECTRIC CENTRE  NaN     NaN         NaN
# 2                      TIRUPATI FOOT WEAR  NaN     NaN         NaN
# 3  SUPA DEURALI ALMUNIUM AND STEEL UDHYOG  NaN     NaN         NaN
# 4   MAHALAXMI DEVI REFRIGERATION WORKSHOP  NaN     NaN         NaN
#
#    CitizenshipDetails  PassportDetails  DrivingLicenseDetails  VoterIDDetails  \
# 0                 NaN              NaN                    NaN             NaN
# 1                 NaN              NaN                    NaN             NaN
# 2                 NaN              NaN                    NaN             NaN
# 3                 NaN              NaN                    NaN             NaN
# 4                 NaN              NaN                    NaN             NaN
#
#                        PANDetails  \
# 0  606804729|2075-12-12|Kathmandu
# 1      602297651|2071-04-22|Banke
# 2   602164991|2071-02-22|Sunasari
# 3  611769888|2076-05-18|Rupandehi
# 4  615455828|2077-11-26|Bhaktapur
#
#                                       CompanyDetails  IndianEmbassyDetails  \
# 0    211424/075/076|NULL|Office Of Company Registrar                   NaN
# 1  23554-071/072|NULL|Department of commerce and ...                   NaN
# 2  13105/074/075|NULL|Office of Cottage and Small...                   NaN
# 3  19006/076/77|NULL|Office of Cottage and Small ...                   NaN
# 4             63|NULL|District Development Committee                   NaN
#
#                                           BlackLists
# 0  Bank and Financial Institutions|32165|2078-11-...
# 1  Bank and Financial Institutions|32166|2078-11-...
# 2  Bank and Financial Institutions|32809|2078-11-...
# 3  Bank and Financial Institutions|33066|2078-11-...
# 4  Bank and Financial Institutions|32147|2078-11-...

# %%
import xmltodict
import json

xml_data = r"C:\Users\Administrator\Downloads\data.json"
# Convert XML to dictionary
dict_data = xmltodict.parse(xml_data)

# Convert dictionary to JSON
json_data = json.dumps(dict_data, indent=4)

# Specify the file path to save the JSON data
file_path = '/output/jdata.json'

# Write JSON data to a file
with open(file_path, 'w') as json_file:
    json_file.write(json_data)

print(f'JSON data has been stored in {file_path}')
# Out:
# ---------------------------------------------------------------------------
# ExpatError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20944\2040135325.py in <module>
#       4 xml_data = r"C:\Users\Administrator\Downloads\data.json"
#       5 # Convert XML to dictionary
# ----> 6 dict_data = xmltodict.parse(xml_data)
#       7
#       8 # Convert dictionary to JSON
#
# c:\ProgramData\Anaconda3\lib\site-packages\xmltodict.py in parse(xml_input, encoding, expat, process_namespaces, namespace_separator, disable_entities, process_comments, **kwargs)
#     376         parser.Parse(b'',True)
#     377     else:
# --> 378         parser.Parse(xml_input, True)
#     379     return handler.item
#     380
#
# ExpatError: not well-formed (invalid token): line 1, column 2

# %%
data = {
    'Account Name': 'Sabin Lamichhanne',
    'name_percent': '20.0',
    'Cib name':'sabin lamichhane',
    'CBS Father name': 'kabin lamichhane',
    'fathersname_percent':'',
    'Cib father name':'kabin lamichhane',
    'Date of birth':'2056',
    'nepdate_percent':'',
    'cib dob':'2056-04-07',
    'CBS citizenship':'',
    'citizenship_percent':'',
    'cib citizenship no':'948474664',
    'similarity':'',
    'Customer Id': '',
    'Clientstatus':'',
    'dlicenceidno':'',
    'indianembassyregno':'',
    'Result of Cib Screening':'',
    'cib gender':'m',
    'Blacklisted no':'12345',
    'Blacklisted date':'',
    'account Number':'09877654',
    'branchcode':'220',
    'Current Status':'debit restrict'

}

# %%
import pandas as pd
from openpyxl import Workbook
from openpyxl.styles import PatternFill, Alignment

# Sample data
data = {
    'Column1': [1, 2, 3, 4, 5],
    'Column2': [10, 20, 30, 40, 50],
    'Column3': [100, 200, 300, 400, 500]
}

# Create a DataFrame from the data
df = pd.DataFrame(data)

# Create a new Excel writer object
excel_writer = pd.ExcelWriter('output.xlsx', engine='openpyxl')

# Write the DataFrame to Excel starting from the second row
df.to_excel(excel_writer, index=False, startrow=2, header=False, sheet_name='Sheet1')

# Get the workbook and worksheet objects
workbook = excel_writer.book
worksheet = excel_writer.sheets['Sheet1']

# Add description above the table and center it
description = 'This is a sample Excel table description.'
description_cell = worksheet.cell(row=1, column=1, value=description)
description_cell.alignment = Alignment(horizontal='center')

# Leave one blank row above the table
blank_row = worksheet.cell(row=2, column=1, value='')

# Highlight all columns and rows with values
for row_idx, row in enumerate(worksheet.iter_rows(min_row=3, max_row=len(df) + 2, values_only=True), start=3):
    for col_idx, cell_value in enumerate(row, start=1):
        if cell_value:
            worksheet.cell(row=row_idx, column=col_idx).fill = PatternFill(start_color='FFFF00',
                                                                           end_color='FFFF00',
                                                                           fill_type='solid')

# Save the Excel file
excel_writer.save()

print("Columns and rows with values highlighted in the Excel file.")
# Out:
# Columns and rows with values highlighted in the Excel file.
