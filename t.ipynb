# %%
import json
import pandas as pd

file = open(r"D:\BOT_Prime\CIB_DELTA_back\output\data.json")
datas = json.load(file)
df = pd.DataFrame(columns=[
        'Name',
        'DOB', 
        'Gender', 
        'FatherName', 
        'CitizenshipDetails', 
        'PassportDetails', 
        'DrivingLicenseDetails',
        'VoterIDDetails',
        'PANDetails', 
        'CompanyDetails',
        'IndianEmbassyDetails',
        'BlackLists' 
    ])

num = 0
for data in datas["BulkOffLoading"]["Individuals"]["Item"]:
    # for key_value in data:
    # print("--------------------------- REal Data --------------------- \n")
    # print(data)
    dicts = {}
    data_keys = list(data.keys())
    # print(data_keys)
    for data_key in data_keys:
        # print(data_key)
        if isinstance(data[data_key], str):
            dicts[data_key] = data[data_key]
            print(dicts[data_key])
        
        else:
            # maintain Citizenship details and black list detail
            keys = list(data[data_key].keys())
            data_count = int(data[data_key][keys[0]])
            # print('DATA_COUNT',data_count)
            if data_count > 1: #here data with data_count greater than 1 will come in list format
                details = data[data_key][keys[1]]
                # if details contain 
                print('DETAILS',details)
                dicts[data_key] = ['|'.join(entry.values()) for entry in details] 
                print(dicts[data_key])
                
            elif data_count == 0:
                continue
            else:
                details = data[data_key][keys[1]]
                # print('next detail',details)
                dicts[data_key] = '|'.join(details.values())
            # df.loc[len(df)] = dicts
            
    # print(dicts)
    # print(f"--------------- Processed Data number {num} -----------------------" )
    print('Dictionary==========================================================>',dicts)
    num += 1
    if num == 2:
        break
    df.loc[len(df)] = dicts
# Out:
# BALRAM PRADHAN
# 2015-03-15
# M
# JITENDRA PRADHAN
# DETAILS [{'Sector': 'Bank and Financial Institutions', 'BlacklistNumber': '5432', 'BlacklistedDate': '2071-01-21', 'BlacklistType': 'CF', 'NatureOfRelation': 'Guarantor'}, {'Sector': 'Bank and Financial Institutions', 'BlacklistNumber': '5432', 'BlacklistedDate': '2071-01-21', 'BlacklistType': 'CF', 'NatureOfRelation': 'Partner'}]
# ['Bank and Financial Institutions|5432|2071-01-21|CF|Guarantor', 'Bank and Financial Institutions|5432|2071-01-21|CF|Partner']
# Dictionary==========================================================> {'Name': 'BALRAM PRADHAN', 'DOB': '2015-03-15', 'Gender': 'M', 'FatherName': 'JITENDRA PRADHAN', 'CitizenshipDetails': '2827|2046-01-11|Kathmandu', 'BlackLists': ['Bank and Financial Institutions|5432|2071-01-21|CF|Guarantor', 'Bank and Financial Institutions|5432|2071-01-21|CF|Partner']}
# BHADRA BARAILI
# 2004-11-22
# M
# SAL BAHADUR BARAILI
# ...

# %%
df.count()
# Out:
# Name                     7
# DOB                      7
# Gender                   7
# FatherName               7
# CitizenshipDetails       7
# PassportDetails          0
# DrivingLicenseDetails    0
# VoterIDDetails           0
# PANDetails               2
# CompanyDetails           0
# IndianEmbassyDetails     0
# BlackLists               7
# dtype: int64

# %%
df.head(10)
# Out:
#                   Name         DOB Gender             FatherName  \
# 0       BALRAM PRADHAN  2015-03-15      M       JITENDRA PRADHAN
# 1       BHADRA BARAILI  2004-11-22      M    SAL BAHADUR BARAILI
# 2    SUDHA DEVI DARUKA  2030-01-01      F      SAWAR MAL RANGUTA
# 3     RAJESH RAJ VERMA  2030-08-22      M      KRISHNA RAJ VERMA
# 4         NEELAM RIJAL  2029-05-21      F     TARAK PRASAD RIJAL
# 5           JIVAN GIRI  2036-01-29      M       RAM CHANDRA GIRI
# 6  KUMAR ROKKA CHHETRI  2031-02-29      M  BASANTA ROKKA CHHETRI
#
#                                   CitizenshipDetails  PassportDetails  \
# 0                          2827|2046-01-11|Kathmandu              NaN
# 1                2061/30387|2041-08-29|Sankhuwasabha              NaN
# 2                             10523|2068-08-04|Parsa              NaN
# 3                            5237|2047-07-20|Saptari              NaN
# 4                            22961|2052-08-13|Morang              NaN
# ...

# %%
import numpy as np
def drop_dupicates(df):
    both_present = df[(~df['CitizenshipDetails'].isnull()) & (~df['PANDetails'].isnull())]
    # both_present
    duplicated_rows = both_present.copy()
    # duplicated_rows
    both_present_indices = both_present.index 

    df.drop(index=both_present_indices, inplace=True)
    for index, row in both_present.iterrows():
        both_present.at[index, 'CitizenshipDetails'] = np.nan

    for index, row in duplicated_rows.iterrows():
        duplicated_rows.at[index, 'PANDetails'] = np.nan

    df = pd.concat([df, both_present, duplicated_rows], ignore_index=True)
    return df
data_df = drop_dupicates(df)

# %%
df.count()
# Out:
# Name                     24
# DOB                      24
# Gender                   24
# FatherName               24
# CitizenshipDetails       24
# PassportDetails           0
# DrivingLicenseDetails     0
# VoterIDDetails            1
# PANDetails                0
# CompanyDetails            0
# IndianEmbassyDetails      0
# BlackLists               24
# dtype: int64

# %%
data =    {
                    "Name": "JIVAN GIRI",
                    "DOB": "2036-01-29",
                    "Gender": "M",
                    "FatherName": "RAM CHANDRA GIRI",
                    "CitizenshipDetails": {
                        "CitizenshipCount": "1",
                        "Citizenship": {
                            "CitizenshipNumber": "2727/5942",
                            "CitizenshipIssuedDate": "2052-04-22",
                            "CitizenshipIssuedDistrict": "Morang"
                        }
                    },
                    "PassportDetails": {
                        "PassportCount": "0"
                    },
                    "DrivingLicenseDetails": {
                        "DrivingLicenseCount": "0"
                    },
                    "VoterIDDetails": {
                        "VoterIdCount": "0"
                    },
                    "PANDetails": {
                        "PANCount": "1",
                        "PAN": {
                            "PAN": "304598155",
                            "PANIssuedDate": "2067-12-09",
                            "PANIssuedDistrict": "Jhapa"
                        }
                    },
                    "IndianEmbassyDetails": {
                        "IndianEmbassyCount": "0"
                    },
                    "BlackLists": {
                        "BlackListCount": "1",
                        "BlackList": {
                            "Sector": "Bank and Financial Institutions",
                            "BlacklistNumber": "69325",
                            "BlacklistedDate": "2080-02-29",
                            "BlacklistType": "CF",
                            "NatureOfRelation": "Guarantor"
                        }
                    }
                }

# %%
dicts = {}
df = pd.DataFrame(columns=[
        'Name',
        'DOB', 
        'Gender', 
        'FatherName', 
        'CitizenshipDetails', 
        'PassportDetails', 
        'DrivingLicenseDetails',
        'VoterIDDetails',
        'PANDetails', 
        'CompanyDetails',
        'IndianEmbassyDetails',
        'BlackLists' 
    ])
        
dicts = {}
data_keys = list(data.keys())
# print(data_keys)
for data_key in data_keys:
    # print(data_key)
    if isinstance(data[data_key], str):
        dicts[data_key] = data[data_key]
        print(dicts[data_key])
    
    else:
        # maintain Citizenship details and black list detail
        keys = list(data[data_key].keys())
        data_count = int(data[data_key][keys[0]])
        # print('DATA_COUNT',data_count)
        if data_count > 1: #here data with data_count greater than 1 will come in list format
            details = data[data_key][keys[1]]
            # if details contain 
            print('DETAILS',details)
            dicts[data_key] = ['|'.join(entry.values()) for entry in details] 
            print(dicts[data_key])
            df.loc[len(df)] = dicts
            
        elif data_count == 0:
            dicts[data_key] =''
            continue
        else:
            details = data[data_key][keys[1]]
            # if 'CitizenshipNumber' in details:
        
            # print('next detail',details)
            dicts[data_key] = '|'.join(details.values())
            print('else==>',dicts[data_key])
            df.loc[len(df)] = dicts

# df.loc[len(df)] = dicts
# Out:
# JIVAN GIRI
# 2036-01-29
# M
# RAM CHANDRA GIRI
# else==> 2727/5942|2052-04-22|Morang
# else==> 304598155|2067-12-09|Jhapa
# else==> Bank and Financial Institutions|69325|2080-02-29|CF|Guarantor

# %%
df
# Out:
#          Name         DOB Gender        FatherName  \
# 0  JIVAN GIRI  2036-01-29      M  RAM CHANDRA GIRI
# 1  JIVAN GIRI  2036-01-29      M  RAM CHANDRA GIRI
# 2  JIVAN GIRI  2036-01-29      M  RAM CHANDRA GIRI
#
#             CitizenshipDetails PassportDetails DrivingLicenseDetails  \
# 0  2727/5942|2052-04-22|Morang             NaN                   NaN
# 1  2727/5942|2052-04-22|Morang
# 2  2727/5942|2052-04-22|Morang
#
#   VoterIDDetails                  PANDetails  CompanyDetails  \
# 0            NaN                         NaN             NaN
# 1                 304598155|2067-12-09|Jhapa             NaN
# 2                 304598155|2067-12-09|Jhapa             NaN
#
#   IndianEmbassyDetails                                         BlackLists
# 0                  NaN                                                NaN
# 1                  NaN                                                NaN
# 2                       Bank and Financial Institutions|69325|2080-02-...

# %%
df.head(20)
# Out:
#                                                 Name  DOB  Gender  FatherName  \
# 0                      AALI SUB REMIT SEWA PVT. LTD.  NaN     NaN         NaN
# 1                             RECHAL ELECTRIC CENTRE  NaN     NaN         NaN
# 2                                 TIRUPATI FOOT WEAR  NaN     NaN         NaN
# 3             SUPA DEURALI ALMUNIUM AND STEEL UDHYOG  NaN     NaN         NaN
# 4              MAHALAXMI DEVI REFRIGERATION WORKSHOP  NaN     NaN         NaN
# 5                                SHIVSHAKTI HARDWARE  NaN     NaN         NaN
# 6   AJIMA ORGANIC KRISHI AND PASHUPALAN FARM PVT LTD  NaN     NaN         NaN
# 7                                   RAGINI SUPPLIERS  NaN     NaN         NaN
# 8                             BAJRA GURU ENTERPRISES  NaN     NaN         NaN
# 9                               RARAHANG NIRMAN SEWA  NaN     NaN         NaN
# 10                               VANADIUM TRADE LINK  NaN     NaN         NaN
# ...

# %%
import json
import pandas as pd

file = open(r"D:\BOT_Prime\CIB_DELTA_back\output\data.json")
datas = json.load(file)
df = pd.DataFrame(columns=[
        'Name',
        'DOB', 
        'Gender', 
        'FatherName', 
        'CitizenshipDetails', 
        'PassportDetails', 
        'DrivingLicenseDetails',
        'VoterIDDetails',
        'PANDetails', 
        'CompanyDetails',
        'IndianEmbassyDetails',
        'BlackLists' 
    ])

num = 0
for data in datas["BulkOffLoading"]["Institutions"]["Item"]:
    # print(data)
    # data = 
    data_list = []
    dicts = {}
    data_keys = list(data.keys())
    # print(data_keys)
    for data_key in data_keys[:1]:
        dicts[data_key] = data[data_key]
        # print(dicts)
    for data_key in sorted(data_keys[1:]):
        # print(data_key)
        # print(data[data_key])
        keys = list(data[data_key].keys())
        # print('key------------',keys)
        data_count = int(data[data_key][keys[0]])
        if data_count > 1:
            details = data[data_key][keys[1]]
            # print('detail',details)
            if "BlackList" in data_key:
                dicts[data_key] = ['|'.join(detail.values()) for detail in details]
                # print(dicts)
                continue
            else:  
                for detail in details:
                    dicts[data_key] = '|'.join(detail.values())
                    # print('detttttttttttttttt',dicts[data_key])
                    # print('COUNT GREATER THAN 1',dicts)
                    df.loc[len(df)] = dicts
        elif data_count == 0:
            continue
        else:
            details = data[data_key][keys[1]]
            # print('DETAIL',details)
            dicts[data_key] = '|'.join(details.values())
            # df.loc[len(df)] = dicts
            # print(dicts)
        # if "BlackList" not in data_key:
            # df.loc[len(df)] = dicts
        #     print('================',dicts[data_key])
        #     print('================',dicts)
            # del dicts[data_key]
            # print('TTTTTTTTTTt================',dicts)
    df.loc[len(df)] = dicts
    num += 1
    if num == 60:
        break
    # df.to_excel('black_institutional.xlsx',index=False)

# %%
df.head(30)
# Out:
#                                                 Name  DOB  Gender  FatherName  \
# 0                      AALI SUB REMIT SEWA PVT. LTD.  NaN     NaN         NaN
# 1                             RECHAL ELECTRIC CENTRE  NaN     NaN         NaN
# 2                                 TIRUPATI FOOT WEAR  NaN     NaN         NaN
# 3             SUPA DEURALI ALMUNIUM AND STEEL UDHYOG  NaN     NaN         NaN
# 4              MAHALAXMI DEVI REFRIGERATION WORKSHOP  NaN     NaN         NaN
# 5                                SHIVSHAKTI HARDWARE  NaN     NaN         NaN
# 6   AJIMA ORGANIC KRISHI AND PASHUPALAN FARM PVT LTD  NaN     NaN         NaN
# 7                                   RAGINI SUPPLIERS  NaN     NaN         NaN
# 8                             BAJRA GURU ENTERPRISES  NaN     NaN         NaN
# 9                               RARAHANG NIRMAN SEWA  NaN     NaN         NaN
# 10                               VANADIUM TRADE LINK  NaN     NaN         NaN
# ...

# %%
import json
import pandas as pd

file = open(r"D:\BOT_Prime\CIB_DELTA_back\output\data.json")
datas = json.load(file)
df = pd.DataFrame(columns=[
        'Name',
        'DOB', 
        'Gender', 
        'FatherName', 
        'CitizenshipDetails', 
        'PassportDetails', 
        'DrivingLicenseDetails',
        'VoterIDDetails',
        'PANDetails', 
        'CompanyDetails',
        'IndianEmbassyDetails',
        'BlackLists' 
    ])

num = 0
for data in datas["BulkOffLoading"]["Institutions"]["Item"]: 
    dicts = {}
    data_keys = list(data.keys())
    # print(data_keys)
    for data_key in data_keys[:1]:
        dicts[data_key] = data[data_key]
        # print(dicts)
    for data_key in sorted(data_keys[1:]):
        # print(data_key)
        # print(data[data_key])
        keys = list(data[data_key].keys())
        # print('key------------',keys)
        data_count = int(data[data_key][keys[0]])
        print(data_count)
        if 'PANDetails' in data_key:
            details = data[data_key][keys[1]]
            dicts[data_key] = '|'.join(details.values())
            print('pan========================',dicts)
        if data_count == 1:
            details = data[data_key][keys[1]]
            dicts[data_key] = '|'.join(details.values())
            print('DATACOUNT IS EQUAL TO ONE',dicts)
        elif data_count > 1:
            details = data[data_key][keys[1]]
            # print('detail',details)
            if "BlackList" in data_key:
                dicts[data_key] = ['|'.join(detail.values()) for detail in details]
                # print(dicts)
                continue
                
            else:  
                for detail in details:
                    dicts[data_key] = '|'.join(detail.values())
                    # print('detttttttttttttttt',dicts[data_key])
                    print('COUNT GREATER THAN 1',dicts)
                    df.loc[len(df)] = dicts
        elif data_count == 0:
            continue
# Out:
# 1
# DATACOUNT IS EQUAL TO ONE {'Name': 'AALI SUB REMIT SEWA PVT. LTD.', 'BlackLists': 'Bank and Financial Institutions|32165|2078-11-08|NON CF|Borrower'}
# 1
# DATACOUNT IS EQUAL TO ONE {'Name': 'AALI SUB REMIT SEWA PVT. LTD.', 'BlackLists': 'Bank and Financial Institutions|32165|2078-11-08|NON CF|Borrower', 'CompanyDetails': '211424/075/076|NULL|Office Of Company Registrar'}
# 1
# pan======================== {'Name': 'AALI SUB REMIT SEWA PVT. LTD.', 'BlackLists': 'Bank and Financial Institutions|32165|2078-11-08|NON CF|Borrower', 'CompanyDetails': '211424/075/076|NULL|Office Of Company Registrar', 'PANDetails': '606804729|2075-12-12|Kathmandu'}
# DATACOUNT IS EQUAL TO ONE {'Name': 'AALI SUB REMIT SEWA PVT. LTD.', 'BlackLists': 'Bank and Financial Institutions|32165|2078-11-08|NON CF|Borrower', 'CompanyDetails': '211424/075/076|NULL|Office Of Company Registrar', 'PANDetails': '606804729|2075-12-12|Kathmandu'}
# 1
# ...

# %%
# df.head(50)

# %%
import pandas as pd

df = pd.DataFrame(columns=[
        'Name',
        'DOB', 
        'Gender', 
        'FatherName', 
        'CitizenshipDetails', 
        'PassportDetails', 
        'DrivingLicenseDetails',
        'VoterIDDetails',
        'PANDetails', 
        'CompanyDetails',
        'IndianEmbassyDetails',
        'BlackLists' 
    ])



data = {
                    "Name": "KOHINOOR SUPPLIERS",
                    "PANDetails": {
                        "PANCount": "1",
                        "PAN": {
                            "PAN": "600534811",
                            "PANIssuedDate": "2069-01-20",
                            "PANIssuedDistrict": "Sunasari"
                        }
                    },
                    "CompanyDetails": {
                        "CompanyCount": "2",
                        "Company": [
                            {
                                "CompanyRegNumber": "1872/069/070",
                                "CompanyRegDate": "NULL",
                                "CompanyRegAuth": "Department of Commerce"
                            },
                            {
                                "CompanyRegNumber": "1872/069/070",
                                "CompanyRegDate": "NULL",
                                "CompanyRegAuth": "Office of Cottage and Small Industry"
                            }
                        ]
                    },
                    "BlackLists": {
                        "BlackListCount": "3",
                        "BlackList": [
                            {
                                "Sector": "Bank and Financial Institutions",
                                "BlacklistNumber": "45442",
                                "BlacklistedDate": "2079-06-05",
                                "BlacklistType": "NON CF",
                                "NatureOfRelation": "Borrower"
                            },
                            {
                                "Sector": "Bank and Financial Institutions",
                                "BlacklistNumber": "32402",
                                "BlacklistedDate": "2078-11-12",
                                "BlacklistType": "NON CF",
                                "NatureOfRelation": "Borrower"
                            },
                            {
                                "Sector": "Bank and Financial Institutions",
                                "BlacklistNumber": "33589",
                                "BlacklistedDate": "2078-12-10",
                                "BlacklistType": "NON CF",
                                "NatureOfRelation": "Borrower"
                            }
                        ]
                    }
                }

#  data_list = []
dicts = {}
data_keys = list(data.keys())
# print(data_keys)
for data_key in data_keys[:1]:
    dicts[data_key] = data[data_key]
    # print(dicts)
for data_key in sorted(data_keys[1:]):
    # print(data_key)
    # print(data[data_key])
    keys = list(data[data_key].keys())
    # print('key------------',keys)
    data_count = int(data[data_key][keys[0]])
    print(data_count)
    if 'PANDetails' in data_key:
        details = data[data_key][keys[1]]
        dicts[data_key] = '|'.join(details.values())
        print('pan========================',dicts)
    if data_count == 1:
        details = data[data_key][keys[1]]
        dicts[data_key] = '|'.join(details.values())
        print('DATACOUNT IS EQUAL TO ONE',dicts)
    elif data_count > 1:
        details = data[data_key][keys[1]]
        # print('detail',details)
        if "BlackList" in data_key:
            dicts[data_key] = ['|'.join(detail.values()) for detail in details]
            # print(dicts)
            continue
            
        else:  
            for detail in details:
                dicts[data_key] = '|'.join(detail.values())
                # print('detttttttttttttttt',dicts[data_key])
                print('COUNT GREATER THAN 1',dicts)
                df.loc[len(df)] = dicts
    elif data_count == 0:
        continue
    # else:
    #     details = data[data_key][keys[1]]
    #     # print('DETAIL',details)
    #     dicts[data_key] = '|'.join(details.values())
    #     df.loc[len(df)] = dicts
    #     # print(dicts)
    # if "BlackList" not in data_key:
    #     df.loc[len(df)] = dicts
    #     print('================',dicts[data_key])
    #     print('================',dicts)
        # del dicts[data_key]
        # print('TTTTTTTTTTt================',dicts)
# df.loc[len(df)] = dicts
# Out:
# 3
# 2
# COUNT GREATER THAN 1 {'Name': 'KOHINOOR SUPPLIERS', 'BlackLists': ['Bank and Financial Institutions|45442|2079-06-05|NON CF|Borrower', 'Bank and Financial Institutions|32402|2078-11-12|NON CF|Borrower', 'Bank and Financial Institutions|33589|2078-12-10|NON CF|Borrower'], 'CompanyDetails': '1872/069/070|NULL|Department of Commerce'}
# COUNT GREATER THAN 1 {'Name': 'KOHINOOR SUPPLIERS', 'BlackLists': ['Bank and Financial Institutions|45442|2079-06-05|NON CF|Borrower', 'Bank and Financial Institutions|32402|2078-11-12|NON CF|Borrower', 'Bank and Financial Institutions|33589|2078-12-10|NON CF|Borrower'], 'CompanyDetails': '1872/069/070|NULL|Office of Cottage and Small Industry'}
# 1
# ...

# %%
df
# Out:
#                  Name  DOB  Gender  FatherName  CitizenshipDetails  \
# 0  KOHINOOR SUPPLIERS  NaN     NaN         NaN                 NaN
# 1  KOHINOOR SUPPLIERS  NaN     NaN         NaN                 NaN
#
#    PassportDetails  DrivingLicenseDetails  VoterIDDetails  PANDetails  \
# 0              NaN                    NaN             NaN         NaN
# 1              NaN                    NaN             NaN         NaN
#
#                                       CompanyDetails  IndianEmbassyDetails  \
# 0           1872/069/070|NULL|Department of Commerce                   NaN
# 1  1872/069/070|NULL|Office of Cottage and Small ...                   NaN
#
#                                           BlackLists
# 0  [Bank and Financial Institutions|45442|2079-06...
# 1  [Bank and Financial Institutions|45442|2079-06...

# %%
import pandas as pd

df = pd.DataFrame(columns=[
        'Name',
        'DOB', 
        'Gender', 
        'FatherName', 
        'CitizenshipDetails', 
        'PassportDetails', 
        'DrivingLicenseDetails',
        'VoterIDDetails',
        'PANDetails', 
        'CompanyDetails',
        'IndianEmbassyDetails',
        'BlackLists' 
    ])
    
data = {
                    "Name": "KOHINOOR SUPPLIERS",
                    "PANDetails": {
                        "PANCount": "1",
                        "PAN": {
                            "PAN": "600534811",
                            "PANIssuedDate": "2069-01-20",
                            "PANIssuedDistrict": "Sunasari"
                        }
                    },
                    "CompanyDetails": {
                        "CompanyCount": "2",
                        "Company": [
                            {
                                "CompanyRegNumber": "1872/069/070",
                                "CompanyRegDate": "NULL",
                                "CompanyRegAuth": "Department of Commerce"
                            },
                            {
                                "CompanyRegNumber": "1872/069/070",
                                "CompanyRegDate": "NULL",
                                "CompanyRegAuth": "Office of Cottage and Small Industry"
                            }
                        ]
                    },
                    "BlackLists": {
                        "BlackListCount": "3",
                        "BlackList": [
                            {
                                "Sector": "Bank and Financial Institutions",
                                "BlacklistNumber": "45442",
                                "BlacklistedDate": "2079-06-05",
                                "BlacklistType": "NON CF",
                                "NatureOfRelation": "Borrower"
                            },
                            {
                                "Sector": "Bank and Financial Institutions",
                                "BlacklistNumber": "32402",
                                "BlacklistedDate": "2078-11-12",
                                "BlacklistType": "NON CF",
                                "NatureOfRelation": "Borrower"
                            },
                            {
                                "Sector": "Bank and Financial Institutions",
                                "BlacklistNumber": "33589",
                                "BlacklistedDate": "2078-12-10",
                                "BlacklistType": "NON CF",
                                "NatureOfRelation": "Borrower"
                            }
                        ]
                    }
                }
for key, value in data.items():
    if key == "CompanyDetails":
        for company in value['Company']:
            row_data = {
                "Name": data["Name"],
                "PANDetails": '|'.join(data["PANDetails"]["PAN"].values()),
                "CompanyDetails": '|'.join(company.values()),
                "BlackLists": '|'.join(blacklist.values())  # Assuming blacklist is defined somewhere
            }
            df = df.append(row_data, ignore_index=True)
    else:
        # Handle other keys in a similar way if needed
        pass

# print(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13760\1535120158.py in <module>
#      75                 "PANDetails": '|'.join(data["PANDetails"]["PAN"].values()),
#      76                 "CompanyDetails": '|'.join(company.values()),
# ---> 77                 "BlackLists": '|'.join(blacklist.values())  # Assuming blacklist is defined somewhere
#      78             }
#      79             df = df.append(row_data, ignore_index=True)
#
# NameError: name 'blacklist' is not defined

# %%
import pandas as pd
from openpyxl import Workbook 
from openpyxl.worksheet.datavalidation import DataValidation

# Sample data for the DataFrame
data = {
    'Name': ['John', 'Alice', 'Bob'],
    'Father_Name': ['Doe', 'Smith', 'Johnson'],
    'Gender': ['Male', 'Female', 'Male']
}

# Create a DataFrame from the data
df = pd.DataFrame(data)

# Create a new Excel writer object
excel_writer = pd.ExcelWriter('output.xlsx', engine='openpyxl')

# Write the DataFrame to Excel
df.to_excel(excel_writer, index=False, sheet_name='Sheet1')

# Get the workbook and worksheet objects
workbook = excel_writer.book
worksheet = excel_writer.sheets['Sheet1']

# Define the list of options for the dropdown
gender_options = ['Male', 'Female']

# Define the range where the dropdown will be applied (assuming Gender column starts from column C)
dropdown_range = 'C2:C{}'.format(len(df) + 1)

# Create a DataValidation object for the dropdown
data_validation = DataValidation(type="list", formula1='"{}"'.format(','.join(gender_options)), allow_blank=True)

# Add the data validation to the specific column
worksheet.add_data_validation(data_validation)
data_validation.add(dropdown_range)

# Save the Excel file
excel_writer.save()

print("Dropdown list added to the 'Gender' column in the Excel file.")
# Out:
# Dropdown list added to the 'Gender' column in the Excel file.
